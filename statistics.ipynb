# %% [markdown]
# # Estadística Descriptiva.📉
#
# **Gráfica puntos dada una tabla de frequencia.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
edades = [5, 5, 6, 6, 6, 7, 7, 7, 7, 8, 8, 9]

# %%
Age = pd.Series(edades)

# %%
Frequency = Age.value_counts()
print(Frequency)
# Out:
# 7    4
# 6    3
# 5    2
# 8    2
# 9    1
# Name: count, dtype: int64

# %%
df = Frequency.to_frame(name = 'Frecuency')

# %%
df
# Out:
#    Frecuency
# 7          4
# 6          3
# 5          2
# 8          2
# 9          1

# %%
df = df.reset_index().rename(columns={'index' : 'Edad'})

# %%
df
# Out:
#    Edad  Frecuency
# 0     7          4
# 1     6          3
# 2     5          2
# 3     8          2
# 4     9          1

# %%
plt.scatter(df['Edad'], df['Frecuency'], alpha=0.7)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Edades')
plt.xticks(df['Edad'].unique())
plt.yticks(df['Frecuency'].unique())
# Out:
# ([<matplotlib.axis.YTick at 0x6ce2b48>,
# ...
#  [Text(0, 4, '4'), Text(0, 3, '3'), Text(0, 2, '2'), Text(0, 1, '1')])

# %% [markdown]
# ## Preguntas:
#
# **Edad más frecuente:** 7
#
# **Datos con Edad > 7:** 3
#
# **Rango (Max - Min):** 4

# %% [markdown]
# # Gráfica de barras.
#
# **28 profesores respondieron cual es su curso favorito:**
#
# 7 Historia, 1 Matematicas, 1 Fisica, 10 Geometria y 9 Lenguaje.

# %%
materias = ['Historia', 'Matematicas', 'Fisica', 'Geometria', 'Lenguaje']
cantidad = [7,1,1,10,9]

# %%
plt.bar(materias, cantidad)
plt.title('Cursos Preferidos')
plt.xlabel('Cursos', labelpad=20)
plt.ylabel('Cantidad', labelpad=20)
# Out:
# Text(0, 0.5, 'Cantidad')
